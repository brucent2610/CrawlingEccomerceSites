# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
data = pd.read_csv("./data/top_10_lowest_price.csv")

# %%
data.head(5)
# Out:
#    product_id                                               name  price
# 0   144640385  Túi Đóng Hàng, Túi Đóng Gói Bóng Khí Hồng , Đe...    800
# 1   141656405  Đồng tiền xu ngũ đế, âm dương, gieo quẻ, phong...    931
# 2    98030640  Viên Sủi Rửa Kính Ô Tô - Tẩy Sạch Kính - Tạo H...    980
# 3    85805268     VIÊN SỦI RỬA KÍNH Ô TÔ (1 VIÊN PHA 4 LÍT NƯỚC)    980
# 4   115623003  Sủi rửa kính ô tô, pha 1 viên sủi rửa kính với...    980

# %%
Y_axis = np.arange(len(data["name"]))

plt.barh(Y_axis + 0.2, data["price"], 0.4)

plt.yticks(Y_axis, data["name"])
plt.xlabel("Price")
plt.ylabel("Products")
plt.title("Top 10 Rating")
plt.ticklabel_format(style='plain', axis='x')
plt.show()
